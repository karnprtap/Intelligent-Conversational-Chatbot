# %%
import  numpy as np
import pandas as pd 
import string
import pickle

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
import nltk
nltk.download("punkt")
nltk.download("stopwords")
# ---------------------------
# Download NLTK Data
# ---------------------------
nltk.download("punkt")
nltk.download("punkt_tab")
nltk.download("stopwords")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\shyam\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\shyam\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\shyam\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\shyam\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\shyam\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\shyam\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import pandas as pd
df = pd.read_csv("chatbot_human_interaction.csv")
df.head()
# Out:
#              text    intent                             response
# 0           Hello  greeting           Hello! How can I help you?
# 1              Hi  greeting           Hello! How can I help you?
# 2             Hey  greeting           Hello! How can I help you?
# 3    Good morning  greeting    Good morning! How can I help you?
# 4  Good afternoon  greeting  Good afternoon! How can I help you?

# %%
print(df.shape)
# Out:
# (68, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   text      63 non-null     object
#  1   intent    63 non-null     object
#  2   response  63 non-null     object
# dtypes: object(3)
# memory usage: 1.7+ KB

# %%
df["intent"].value_counts()
# Out:
# intent
# greeting                   15
# goodbye                    10
# python                     10
# machine_learning           10
# artificial_intelligence    10
# thanks                      8
# Name: count, dtype: int64

# %%
# Text cleaning process

stemmer = PorterStemmer()

stop_words = set(stopwords.words("english"))

# %%
def clean_text(text):
    text = text.lower()
    text = text.translate(str.maketrans("", "", string.punctuation))
    words = word_tokenize(text)

    words = [stemmer.stem(word) for word in words if word not in stop_words]

    return " ".join(words)

# %%
df["clean_text"] = df["text"].apply(clean_text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df["clean_text"] = df["text"].apply(clean_text)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\series.py:4935, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4800 def apply(
#    4801     self,
#    4802     func: AggFuncType,
#    (...)   4807     **kwargs,
#    4808 ) -> DataFrame | Series:
#    4809     """
#    4810     Invoke function on values of Series.
#    4811
#    (...)   4926     dtype: float64
#    4927     """
#    4928     return SeriesApply(
#    4929         self,
#    4930         func,
#    4931         convert_dtype=convert_dtype,
#    4932         by_row=by_row,
#    4933         args=args,
#    4934         kwargs=kwargs,
# -> 4935     ).apply()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\apply.py:1422, in SeriesApply.apply(self)
#    1419     return self.apply_compat()
#    1421 # self.func is Callable
# -> 1422 return self.apply_standard()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\apply.py:1502, in SeriesApply.apply_standard(self)
#    1496 # row-wise access
#    1497 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1498 # we need to give `na_action="ignore"` for categorical data.
#    1499 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1500 #  Categorical (GH51645).
#    1501 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1502 mapped = obj._map_values(
#    1503     mapper=curried, na_action=action, convert=self.convert_dtype
#    1504 )
#    1506 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1507     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1508     #  See also GH#25959 regarding EA support
#    1509     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\base.py:925, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     922 if isinstance(arr, ExtensionArray):
#     923     return arr.map(mapper, na_action=na_action)
# --> 925 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File pandas/_libs/lib.pyx:2999, in pandas._libs.lib.map_infer()
#
# Cell In[13], line 2, in clean_text(text)
#       1 def clean_text(text):
# ----> 2     text = text.lower()
#       3     text = text.translate(str.maketrans("", "", string.punctuation))
#       4     words = word_tokenize(text)
#
# AttributeError: 'float' object has no attribute 'lower'

# %%
df.duplicated().sum()
# Out:
# np.int64(4)

# %%
df = df.drop_duplicates()

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df["clean_text"] = df["text"].apply(clean_text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df["clean_text"] = df["text"].apply(clean_text)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\series.py:4935, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4800 def apply(
#    4801     self,
#    4802     func: AggFuncType,
#    (...)   4807     **kwargs,
#    4808 ) -> DataFrame | Series:
#    4809     """
#    4810     Invoke function on values of Series.
#    4811
#    (...)   4926     dtype: float64
#    4927     """
#    4928     return SeriesApply(
#    4929         self,
#    4930         func,
#    4931         convert_dtype=convert_dtype,
#    4932         by_row=by_row,
#    4933         args=args,
#    4934         kwargs=kwargs,
# -> 4935     ).apply()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\apply.py:1422, in SeriesApply.apply(self)
#    1419     return self.apply_compat()
#    1421 # self.func is Callable
# -> 1422 return self.apply_standard()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\apply.py:1502, in SeriesApply.apply_standard(self)
#    1496 # row-wise access
#    1497 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1498 # we need to give `na_action="ignore"` for categorical data.
#    1499 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1500 #  Categorical (GH51645).
#    1501 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1502 mapped = obj._map_values(
#    1503     mapper=curried, na_action=action, convert=self.convert_dtype
#    1504 )
#    1506 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1507     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1508     #  See also GH#25959 regarding EA support
#    1509     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\base.py:925, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     922 if isinstance(arr, ExtensionArray):
#     923     return arr.map(mapper, na_action=na_action)
# --> 925 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File pandas/_libs/lib.pyx:2999, in pandas._libs.lib.map_infer()
#
# Cell In[10], line 2, in clean_text(text)
#       1 def clean_text(text):
# ----> 2     text = text.lower()
#       3     text = text.translate(str.maketrans("", "", string.punctuation))
#       4     words = word_tokenize(text)
#
# AttributeError: 'float' object has no attribute 'lower'

# %%
print(df["text"].isnull().sum())
# Out:
# 1

# %%
import pandas as pd

def clean_text(text):
    if pd.isna(text):
        return ""
    text = str(text).lower()
    return text

# %%
df["clean_text"] = df["text"].apply(clean_text)
df.head()
# Out:
#              text    intent                             response  \
# 0           Hello  greeting           Hello! How can I help you?
# 1              Hi  greeting           Hello! How can I help you?
# 2             Hey  greeting           Hello! How can I help you?
# 3    Good morning  greeting    Good morning! How can I help you?
# 4  Good afternoon  greeting  Good afternoon! How can I help you?
#
#        clean_text
# 0           hello
# 1              hi
# 2             hey
# 3    good morning
# 4  good afternoon

# %%
print(df["text"].isnull().sum())
# Out:
# 1

# %%
# Check how many missing values
print(df["text"].isnull().sum())

# Replace missing values with an empty string
df["text"] = df["text"].fillna("")

# Verify they are gone
print(df["text"].isnull().sum())
# Out:
# 1
# 0

# %%
def clean_text(text):
    text = text.lower()
    text = text.translate(str.maketrans("", "", string.punctuation))
    words = word_tokenize(text)

    words = [stemmer.stem(word) for word in words if word not in stop_words]

    return " ".join(words)

df["clean_text"] = df["text"].apply(clean_text)
df.head()
# Out:
#              text    intent                             response  \
# 0           Hello  greeting           Hello! How can I help you?
# 1              Hi  greeting           Hello! How can I help you?
# 2             Hey  greeting           Hello! How can I help you?
# 3    Good morning  greeting    Good morning! How can I help you?
# 4  Good afternoon  greeting  Good afternoon! How can I help you?
#
#        clean_text
# 0           hello
# 1              hi
# 2             hey
# 3       good morn
# 4  good afternoon

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer()

x = vectorizer.fit_transform(df["clean_text"])
y = df["intent"]   # Make sure this column exists

# %%
print(x,y)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 115 stored elements and shape (64, 60)>
#   Coords	Values
#   (0, 26)	1.0
#   (1, 29)	1.0
#   (2, 28)	1.0
#   (3, 22)	0.6455721564905585
#   (3, 42)	0.7636992803218619
#   (4, 22)	0.6455721564905585
#   (4, 0)	0.7636992803218619
#   (5, 22)	0.6455721564905585
#   (5, 16)	0.7636992803218619
#   (6, 25)	1.0
#   (7, 29)	1.0
#   (8, 45)	0.6728463477088686
#   (8, 40)	0.7397822601109303
#   (10, 26)	0.6728463477088686
#   (10, 9)	0.7397822601109303
#   (11, 28)	0.6728463477088686
#   (11, 6)	0.7397822601109303
#   (12, 44)	0.7825732700310212
#   (12, 27)	0.6225584928606744
#   (13, 27)	1.0
#   (14, 50)	0.7071067811865476
#   (14, 10)	0.7071067811865476
#   (16, 7)	1.0
#   (17, 23)	1.0
#   (18, 49)	0.7071067811865476
#   :	:
#   (53, 34)	0.46132654007845786
#   (53, 38)	0.5186228326794547
#   (53, 3)	0.7198667799272148
#   (54, 5)	0.7071067811865476
#   (54, 31)	0.7071067811865476
#   (55, 19)	0.7862372660230266
#   (55, 1)	0.6179247215613214
#   (56, 57)	0.7675461875883816
#   (56, 1)	0.6409936426506436
#   (57, 55)	0.8075126927112471
#   (57, 1)	0.58985019378672
#   (58, 17)	0.8075126927112471
#   (58, 1)	0.58985019378672
#   (59, 1)	0.5533701299135684
#   (59, 30)	0.8329354712818038
#   (60, 13)	0.5773502691896257
#   (60, 5)	0.5773502691896257
#   (60, 31)	0.5773502691896257
#   (61, 1)	0.4251938952003456
#   (61, 12)	0.6400039654112925
#   (61, 36)	0.6400039654112925
#   (62, 1)	0.5533701299135684
#   (62, 21)	0.8329354712818038
#   (63, 1)	0.5533701299135684
#   (63, 39)	0.8329354712818038 0                    greeting
# 1                    greeting
# 2                    greeting
# 3                    greeting
# 4                    greeting
#                ...
# 63    artificial_intelligence
# 64    artificial_intelligence
# 65    artificial_intelligence
# 66    artificial_intelligence
# 67    artificial_intelligence
# Name: intent, Length: 64, dtype: object

# %%
x_train,x_test,y_train,y_test=train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42
)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)

# %%
model.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 model.fit(x_train, y_train)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_logistic.py:1247, in LogisticRegression.fit(self, X, y, sample_weight)
#    1244 else:
#    1245     _dtype = [np.float64, np.float32]
# -> 1247 X, y = validate_data(
#    1248     self,
#    1249     X,
#    1250     y,
#    1251     accept_sparse="csr",
#    1252     dtype=_dtype,
#    1253     order="C",
#    1254     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1255 )
#    1256 check_classification_targets(y)
#    1257 self.classes_ = np.unique(y)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2971, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2969         y = check_array(y, input_name="y", **check_y_params)
#    2970     else:
# -> 2971         X, y = check_X_y(X, y, **check_params)
#    2972     out = X, y
#    2974 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:1385, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1366 ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
#    1368 X = check_array(
#    1369     X,
#    1370     accept_sparse=accept_sparse,
#    (...)   1382     input_name="X",
#    1383 )
# -> 1385 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1387 check_consistent_length(X, y)
#    1389 return X, y
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:1407, in _check_y(y, multi_output, y_numeric, estimator)
#    1405     estimator_name = _check_estimator_name(estimator)
#    1406     y = column_or_1d(y, warn=True)
# -> 1407     _assert_all_finite(y, input_name="y", estimator_name=estimator_name)
#    1408     _ensure_no_complex_data(y)
#    1409 if y_numeric and hasattr(y.dtype, "kind") and y.dtype.kind == "O":
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:105, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     103 if not is_array_api and X.dtype == np.dtype("object") and not allow_nan:
#     104     if _object_dtype_isnan(X).any():
# --> 105         raise ValueError("Input contains NaN")
#     107 # We need only consider float arrays, hence can early return for all else.
#     108 if not xp.isdtype(X.dtype, ("real floating", "complex floating")):
#
# ValueError: Input contains NaN

# %%
df = df.dropna(subset=["intent"])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
x = vectorizer.fit_transform(df["clean_text"])
y = df["intent"]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)
model.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
from sklearn.metrics import accuracy_score

y_pred = model.predict(x_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9230769230769231

# %%
import pickle

pickle.dump(model, open("chatbot_model.pkl", "wb"))

# %%
import pickle

model = pickle.load(open("chatbot_model.pkl", "rb"))

# %%
print(model)
# Out:
# LogisticRegression(max_iter=1000)

# %%
pickle.dump(vectorizer,open("vectorizer.pk1","wb"))

# %%
print("Model Saved Successfully")
# Out:
# Model Saved Successfully

# %%
import pickle

model = pickle.load(open("chatbot_model.pkl", "rb"))

# %%
import os

print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'chatbot_human_interaction.csv', 'chatbot_model.pkl', 'Untitled.ipynb', 'vectorizer.pk1']

# %%
vectorizer=pickle.load(open("vectorizer.pk1","rb"))

# %%
def get_response(user_input):
    clean = clean_text(user_input)

    # Convert text to TF-IDF vector
    vector = vectorizer.transform([clean])

    # Predict intent
    intent = model.predict(vector)[0]

    # Get response
    response = df[df["intent"] == intent]["response"].iloc[0]

    return response


print("=" * 50)
print("ML CHATBOT")
print("=" * 50)

while True:
    user = input("You: ")

    if user.lower() == "bye":
        print("Bot: Goodbye!")
        break

    response = get_response(user)
    print("Bot:", response)
# Out:
# ==================================================
# ML CHATBOT
# ==================================================
# You:  hi
# Bot: Hello! How can I help you?
# You:  whats your name
# Bot: Hello! How can I help you?

# %%
# Out:
# ==================================================
# ML CHATBOT
# ==================================================
# You: Hi
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 9
#       7     print("Bot:Goodbye!")
#       8     break
# ----> 9 response=get_response(user)
#      10 print("Bot:",response)
#
# Cell In[54], line 3, in get_response(user_input)
#       1 def get_response(user_input):
#       2     clean=clean_text(user_input)
# ----> 3     vector=vectorizer.transform([claim])
#       4     input=model.predict(vector)[0]
#       5     response=df[df["input"]==intent]["response"],iloc[0]
#
# NameError: name 'claim' is not defined
